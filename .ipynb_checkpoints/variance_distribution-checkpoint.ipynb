# %% [markdown]
# # Explore variance distribution

# %%
import scanpy as sc
import numpy as np
import pandas as pd
import tqdm
import os 
import matplotlib.pyplot as plt
import seaborn as sns
import tqdm

# %%
# Import isoform_tools
exec(open("/home/matei/Neuroblastoma-project-course/isoform_tools.py").read())

# %%
#DATA_PATH="C:/Users/Felix/Desktop/vs_code/translational_control/data"

# %%
#adata=sc.read("/adata_thresholded.h5ad")
adata = sc.read("/home/matei/data/adata_neuroblastoma_assigned.h5ad")

# %%
adata=adata[~adata.obs.leiden.isin(["7","10","11","6","11","8"])]

# %%
adata.var["transcript"].unique()
# Out:
# array(['DDX11L1-201', 'WASH7P-304', 'WASH7P-331', ..., 'MT-CYB-201',
#        'MT-TT-201', 'MT-TP-201'], shape=(331361,), dtype=object)

# %%
# Filter on isoform count.
# Read keep isoforms
with open("C:/Users/Felix/Desktop/vs_code/translational_control/information_content/keep_isoforms.txt", "r") as f:
    list_ = f.readlines()


keep=[]
for x in list_:
    keep.append(x[:-1])

# Need to redo keep because it was calculated on adata_preprocessed
keep_new = []
for x in tqdm.tqdm(keep):
    if x in adata.var_names.tolist():
        keep_new.append(x)
adata = adata[:,keep_new]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Filter on isoform count.
#       2 # Read keep isoforms
# ----> 3 with open("C:/Users/Felix/Desktop/vs_code/translational_control/information_content/keep_isoforms.txt", "r") as f:
#       4     list_ = f.readlines()
#       7 keep=[]
#
# File ~/anaconda3/envs/neuroblastoma/lib/python3.14/site-packages/IPython/core/interactiveshell.py:346, in _modified_open(file, *args, **kwargs)
#     339 if file in {0, 1, 2}:
#     340     raise ValueError(
#     341         f"IPython won't let you open fd={file} by default "
#     342         "as it is likely to crash IPython. If you know what you are doing, "
#     343         "you can use builtins' open."
#     344     )
# --> 346 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/Felix/Desktop/vs_code/translational_control/information_content/keep_isoforms.txt'

# %% [markdown]
# ### Filter based on total isoform expression

# %%
# Calculate expr per isoform

expr = np.asarray(adata.X.sum(axis=0)).ravel()

df = pd.DataFrame({
    "transcript": adata.var["transcript"].values,
    "expr": expr
})

sum_iex = df.groupby("transcript")["expr"].sum().to_dict()

# %%
len(df.transcript[df["expr"]>100].tolist())
# Out:
# 978

# %%
iso_to_keep = df.transcript[df["expr"]>100].tolist()

# %%
adata = adata[:, adata.var["transcript"].isin(iso_to_keep)]

# %%
len(adata.var["transcript"].unique())
# Out:
# 978

# %%
len(adata.var["gene"].unique())
# Out:
# 849

# %%
len(adata.var[adata.var["gene"]=="MALAT1"])
# Out:
# 14

# %% [markdown]
# ### Filter based on isoform number (<1)

# %%
gene_list = adata.var["gene"].unique().tolist()

# %%
multi_iso = []

for gene in tqdm.tqdm(gene_list):
    n_iso = len(adata.var[adata.var["gene"]==gene])
    #print(f"n_iso:{n_iso}")
    if n_iso > 1:
        multi_iso.append(gene)

len(multi_iso)
# Out:
# 100%|██████████| 849/849 [00:00<00:00, 1949.86it/s]
# 79

# %%
adata = adata[:, adata.var["gene"].isin(multi_iso)]

# %%
len(adata.var["gene"].unique())
# Out:
# 79

# %% [markdown]
# ### Filter based on total gene expression

# %%
gene_list = adata.var["gene"].unique().tolist() 
sum_gex={} 
for gene in tqdm.tqdm(gene_list): 
    transcripts = adata.var[adata.var["gene"] == gene].index 
    sum_gex[gene] = adata[:, transcripts].X.sum().item()
# Out:
# 100%|██████████| 661/661 [01:53<00:00,  5.80it/s]

# %%
sorted_gex = dict(sorted(sum_gex.items(), key=lambda x: x[1], reverse=True))

plt.figure(figsize=(30, 5))
plt.bar(sorted_gex.keys(), sorted_gex.values())

plt.axhline(y=300, color='red', linestyle='--', linewidth=1)

plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
gex_threshold = 300
selected_genes= []
for x in sum_gex:
    if sum_gex[x] > gex_threshold:
        selected_genes.append(x)
print(len(selected_genes))
# Out:
# 99

# %%
adata = adata[:, adata.var["gene"].isin(selected_genes)]

# %%
len(adata.var["gene"].unique().tolist())
# Out:
# 99

# %%
#gex_threshold = 500
#adata = adata[:,adata.var.sum_gex > gex_threshold]

# %%
adata.shape
# Out:
# (2682, 1627)

# %% [markdown]
# ## Calculate var between leiden

# %%
variances = fetch_isoform_varince(adata,
                    group_by="leiden",
                    gene_name_col="gene",
                    transcript_name_col="transcript"
                   )
# Out:
# Processing AnnData object...
# Aggregating counts in conditions...
# Processing 208 transcripts in chunks of 1000...
# Combining results...

# %%
potential_threshold=0.02

plt.figure(figsize=(8, 6))
sns.violinplot(y=variances)
plt.title('Isoforms variance distribution')
# Add horizontal line
plt.axhline(y=potential_threshold, color='black', linestyle='--', linewidth=2, alpha=0.7, label=f'Threshold = {potential_threshold}')
#plt.ylabel('Isoforms')
plt.tight_layout()

plt.show()

# %%
potential_threshold = 0.02

plt.figure(figsize=(8, 6))
sns.violinplot(y=variances)
plt.title('Isoforms variance distribution')

# Add horizontal line for threshold
plt.axhline(y=potential_threshold, color='black', linestyle='--', linewidth=2, alpha=0.7, label=f'Potential Threshold = {potential_threshold}')

# Add percentile lines
p25 = variances.quantile(0.25)
p50 = variances.quantile(0.50)  # median
p70 = variances.quantile(0.70)
p75 = variances.quantile(0.75)
p80 = variances.quantile(0.80)
p90 = variances.quantile(0.90)  # optional 90th percentile

plt.axhline(y=p25, color='red', linestyle=':', linewidth=1.5, alpha=0.8, label=f'25th percentile = {p25:.3f}')
plt.axhline(y=p50, color='orange', linestyle=':', linewidth=1.5, alpha=0.8, label=f'50th percentile = {p50:.3f}')
plt.axhline(y=p70, color='brown', linestyle=':', linewidth=1.5, alpha=0.8, label=f'70th percentile = {p70:.3f}')
plt.axhline(y=p75, color='green', linestyle=':', linewidth=1.5, alpha=0.8, label=f'75th percentile = {p75:.3f}')
plt.axhline(y=p80, color='pink', linestyle=':', linewidth=1.5, alpha=0.8, label=f'80th percentile = {p80:.3f}')
plt.axhline(y=p90, color='blue', linestyle=':', linewidth=1.5, alpha=0.8, label=f'90th percentile = {p90:.3f}')
plt.ylabel("Variance")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
subset_variances = variances[variances > p25]
isoforms_above_threshold = subset_variances.index.unique().tolist()
genes_above_threshold = adata.var[adata.var.transcript.isin(isoforms_above_threshold)].gene.unique().tolist()

# %%
print(f"Number of isoforms above 25th percentile threshold: {len(isoforms_above_threshold)}")
print(f"Number of genes which have at least one isoform above 25th percentile threshold: {len(genes_above_threshold)}")
# Out:
# Number of isoforms above 25th percentile threshold: 156
# Number of genes which have at least one isoform above 25th percentile threshold: 73

# %%
subset_adata = adata[:,adata.var[adata.var.gene.isin(genes_above_threshold)].index.tolist()]

# %%
subset_adata.var
# Out:
#                      gene  transcript                 transcript_type  \
# ENST00000935136.1   STMN1   STMN1-227                  protein_coding
# ENST00000935134.1   STMN1   STMN1-225                  protein_coding
# ENST00000871164.1   STMN1   STMN1-215                  protein_coding
# ENST00000466213.5    SFPQ    SFPQ-203  protein_coding_CDS_not_defined
# ENST00000357214.6    SFPQ    SFPQ-201                  protein_coding
# ...                   ...         ...                             ...
# ENST00000620145.6    MIAT    MIAT-221                          lncRNA
# ENST00000403230.3   DDX17   DDX17-203                  protein_coding
# ENST00000432525.5   DDX17   DDX17-205  protein_coding_CDS_not_defined
# ENST00000903588.1  PTCHD1  PTCHD1-203                  protein_coding
# ENST00000379361.5  PTCHD1  PTCHD1-201                  protein_coding
#
#                        tag level transcript_support_level  \
# ENST00000935136.1   TAGENE   2.0                  Unknown
# ENST00000935134.1     CCDS   2.0                  Unknown
# ENST00000871164.1     CCDS   2.0                  Unknown
# ENST00000466213.5  Unknown   2.0                      1.0
# ENST00000357214.6     CCDS   2.0                      1.0
# ...                    ...   ...                      ...
# ENST00000620145.6   TAGENE   2.0                      1.0
# ENST00000403230.3     CCDS   2.0                      1.0
# ENST00000432525.5  Unknown   2.0                      2.0
# ENST00000903588.1     CCDS   2.0                  Unknown
# ENST00000379361.5     CCDS   2.0                      1.0
#
#                                                         annot_remark   ERCC  \
# ENST00000935136.1                                         ['LRGASP']  False
# ENST00000935134.1                                         ['LRGASP']  False
# ENST00000871164.1                                     ['DanaFarber']  False
# ENST00000466213.5                                            Unknown  False
# ENST00000357214.6                                    ['MANE_select']  False
# ...                                                              ...    ...
# ENST00000620145.6  ['Assembled from PacBio CLS3 reads', 'MANE_sel...  False
# ENST00000403230.3    ['MANE_select', 'NP_006377.2', 'non-ATG start']  False
# ENST00000432525.5                                            Unknown  False
# ENST00000903588.1                                     ['DanaFarber']  False
# ENST00000379361.5                        ['FLJ30296', 'MANE_select']  False
#
#                       mt   ribo  ...  log1p_total_counts  n_cells         m  \
# ENST00000935136.1  False  False  ...           10.981237     1215 -2.381050
# ENST00000935134.1  False  False  ...           10.980536      644 -2.440875
# ENST00000871164.1  False  False  ...           11.343573      468 -2.464349
# ENST00000466213.5  False  False  ...           11.008492     1240 -2.766480
# ENST00000357214.6  False  False  ...           11.272252     1539 -2.810601
# ...                  ...    ...  ...                 ...      ...       ...
# ENST00000620145.6  False  False  ...           11.763558     1348 -1.702309
# ENST00000403230.3  False  False  ...           12.967550     2246 -0.940599
# ENST00000432525.5  False  False  ...           11.084820      816 -2.778431
# ENST00000903588.1  False  False  ...           10.267815      708 -3.004360
# ENST00000379361.5  False  False  ...           10.218788      861 -2.975325
#
#                           v   n_obs       res            lp        lpa  \
# ENST00000935136.1 -3.564115  1215.0 -0.117612 -2.044909e-02   0.000000
# ENST00000935134.1 -3.054336   644.0  0.452480 -1.902068e+01 -12.078754
# ENST00000871164.1 -2.716525   468.0  0.813974 -4.078773e+01 -32.028011
# ENST00000466213.5 -4.067985  1240.0 -0.231636 -2.320547e-05   0.000000
# ENST00000357214.6 -4.208380  1539.0 -0.327183 -7.645388e-11   0.000000
# ...                     ...     ...       ...           ...        ...
# ENST00000620145.6 -2.299028  1348.0  0.466560 -3.941265e+01 -30.727037
# ENST00000403230.3 -1.646880  2246.0  0.357151 -3.868049e+01 -30.012582
# ENST00000432525.5 -3.765044   816.0  0.083448 -2.147619e+00  -0.362306
# ENST00000903588.1 -3.844945   708.0  0.233887 -6.964440e+00  -3.249757
# ENST00000379361.5 -3.864923   861.0  0.184216 -5.664516e+00  -2.405426
#
#                          qv  highly_variable
# ENST00000935136.1  0.953033            False
# ENST00000935134.1  1.137259             True
# ENST00000871164.1  1.213465             True
# ENST00000466213.5  0.908513            False
# ENST00000357214.6  0.859035            False
# ...                     ...              ...
# ENST00000620145.6  1.209333             True
# ENST00000403230.3  1.207106             True
# ENST00000432525.5  1.027293            False
# ENST00000903588.1  1.072959             True
# ENST00000379361.5  1.063146            False
#
# [186 rows x 26 columns]

# %%
for x in variances.index:
    if "PTCHD1" in x:
        print(variances[x],x)
if "PTCHD1" in subset_adata.var.gene.unique():
    print("ANK2 is in")
# Out:
# 0.005819877 PTCHD1-201
# 0.0058198776 PTCHD1-203
# ANK2 is in

# %%
adata.var[adata.var["gene"]=="NBAS"]
# Out:
#                    gene transcript                 transcript_type  \
# ENST00000442506.5  NBAS   NBAS-206                  protein_coding
# ENST00000700061.1  NBAS   NBAS-208                  protein_coding
# ENST00000700062.1  NBAS   NBAS-209         nonsense_mediated_decay
# ENST00000700065.1  NBAS   NBAS-212  protein_coding_CDS_not_defined
# ENST00000700066.1  NBAS   NBAS-213                  protein_coding
# ENST00000700067.1  NBAS   NBAS-214  protein_coding_CDS_not_defined
# ENST00000700068.1  NBAS   NBAS-215                 retained_intron
# ENST00000700070.1  NBAS   NBAS-217         nonsense_mediated_decay
# ENST00000700071.1  NBAS   NBAS-218  protein_coding_CDS_not_defined
# ENST00000700072.1  NBAS   NBAS-219                 retained_intron
# ENST00000700073.1  NBAS   NBAS-220                 retained_intron
#
#                                       tag level transcript_support_level  \
# ENST00000442506.5            cds_start_NF   2.0                      1.0
# ENST00000700061.1  RNA_Seq_supported_only   2.0                  Unknown
# ENST00000700062.1  RNA_Seq_supported_only   2.0                  Unknown
# ENST00000700065.1  RNA_Seq_supported_only   2.0                  Unknown
# ENST00000700066.1         GENCODE_Primary   2.0                  Unknown
# ENST00000700067.1  RNA_Seq_supported_only   2.0                  Unknown
# ENST00000700068.1  RNA_Seq_supported_only   2.0                  Unknown
# ENST00000700070.1  RNA_Seq_supported_only   2.0                  Unknown
# ENST00000700071.1  RNA_Seq_supported_only   2.0                  Unknown
# ENST00000700072.1  RNA_Seq_supported_only   2.0                  Unknown
# ENST00000700073.1  RNA_Seq_supported_only   2.0                  Unknown
#
#                                                         annot_remark   ERCC  \
# ENST00000442506.5                                            Unknown  False
# ENST00000700061.1                         ['RNA-Seq supported only']  False
# ENST00000700062.1                         ['RNA-Seq supported only']  False
# ENST00000700065.1                         ['RNA-Seq supported only']  False
# ENST00000700066.1  ['CAGE supported TSS', 'RNA-Seq supported only...  False
# ENST00000700067.1                         ['RNA-Seq supported only']  False
# ENST00000700068.1                         ['RNA-Seq supported only']  False
# ENST00000700070.1                         ['RNA-Seq supported only']  False
# ENST00000700071.1                         ['RNA-Seq supported only']  False
# ENST00000700072.1                         ['RNA-Seq supported only']  False
# ENST00000700073.1                         ['RNA-Seq supported only']  False
#
#                       mt   ribo  ...  log1p_total_counts  n_cells         m  \
# ENST00000442506.5  False  False  ...           10.138652      539 -2.789222
# ENST00000700061.1  False  False  ...            9.382200      251 -3.406619
# ENST00000700062.1  False  False  ...            9.076034      261 -3.523656
# ENST00000700065.1  False  False  ...           10.419991      718 -2.362462
# ENST00000700066.1  False  False  ...            9.573392      777 -3.161506
# ENST00000700067.1  False  False  ...            9.633976      897 -3.191831
# ENST00000700068.1  False  False  ...           11.282083      993 -1.925028
# ENST00000700070.1  False  False  ...           11.416638     1201 -1.679796
# ENST00000700071.1  False  False  ...           10.394056      884 -2.314071
# ENST00000700072.1  False  False  ...            9.726684      781 -2.894356
# ENST00000700073.1  False  False  ...            9.473866      816 -2.961975
#
#                           v   n_obs       res          lp         lpa  \
# ENST00000442506.5 -3.161533   539.0  0.697925  -35.159194  -26.559105
# ENST00000700061.1 -3.752257   251.0  0.741396  -19.536473  -12.488469
# ENST00000700062.1 -3.804112   261.0  0.811679  -23.697002  -16.022991
# ENST00000700065.1 -2.745186   718.0  0.682590  -44.135479  -35.231177
# ENST00000700066.1 -4.332783   777.0 -0.092710   -0.103437    0.000000
# ENST00000700067.1 -4.473672   897.0 -0.202373   -0.001235    0.000000
# ENST00000700068.1 -2.274934   993.0  0.713572  -65.210736  -55.635266
# ENST00000700070.1 -1.850058  1201.0  0.893012 -119.540396 -109.468490
# ENST00000700071.1 -2.747154   884.0  0.631897  -46.544283  -37.594520
# ENST00000700072.1 -3.740246   781.0  0.226238   -7.134283   -3.364337
# ENST00000700073.1 -3.821577   816.0  0.213919   -6.778139   -3.127506
#
#                          qv  highly_variable
# ENST00000442506.5  1.196113             True
# ENST00000700061.1  1.139449             True
# ENST00000700062.1  1.156178             True
# ENST00000700065.1  1.223270             True
# ENST00000700066.1  0.970057            False
# ENST00000700067.1  0.931338            False
# ENST00000700068.1  1.278613             True
# ENST00000700070.1  1.393079             True
# ENST00000700071.1  1.230117             True
# ENST00000700072.1  1.074166             True
# ENST00000700073.1  1.071618             True
#
# [11 rows x 26 columns]

# %%
for x in variances.index:
    if "NBAS" in x:
        print(variances[x],x)
if "NBAS" in subset_adata.var.gene.unique():
    print("Sox10 is in")
# Out:
# 0.0005769468 NBAS-206
# 0.00021800985 NBAS-208
# 0.0001972305 NBAS-209
# 0.0015775164 NBAS-212
# 0.0005336931 NBAS-213
# 0.00055041636 NBAS-214
# 0.0016742456 NBAS-215
# 0.0014330369 NBAS-217
# 0.00021098506 NBAS-218
# 0.00056965137 NBAS-219
# 0.0006127638 NBAS-220
